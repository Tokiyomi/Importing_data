# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Remote txt

# %%
import urllib
import urllib3

# %%
http = urllib3.PoolManager()

# %%
r = http.request('GET', 'https://www.gutenberg.org/files/60265/60265-0.txt')
# Out:
# C:\Users\monic\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
r.status
# Out:
# 200

# %%
r.data
# Out:
# b'The Project Gutenberg eBook, The Red Cross Girls on the French Firing\r\nLine, by Margaret Vandercook\r\n\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and most\r\nother parts of the world at no cost and with almost no restrictions \r\nwhatsoever.  You may copy it, give it away or re-use it under the terms of\r\nthe Project Gutenberg License included with this eBook or online at \r\nwww.gutenberg.org.  If you are not located in the United States, you\'ll have\r\nto check the laws of the country where you are located before using this ebook.\r\n\r\n\r\n\r\n\r\nTitle: The Red Cross Girls on the French Firing Line\r\n\r\n\r\nAuthor: Margaret Vandercook\r\n\r\n\r\n\r\nRelease Date: September 8, 2019  [eBook #60265]\r\n\r\nLanguage: English\r\n\r\nCharacter set encoding: UTF-8\r\n\r\n\r\n***START OF THE PROJECT GUTENBERG EBOOK THE RED CROSS GIRLS ON THE FRENCH\r\nFIRING LINE***\r\n\r\n\r\nE-text prepared by Demian Katz, Craig Kirkwood, and the Online Distribut
# ...

# %% [markdown]
# ## Remote csv

# %%
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
c=pd.read_csv(url)

# %%
c.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# ## Remote JSON

# %%
a = http.request('GET', 'https://graph.facebook.com/elhacker.net')
# Out:
# C:\Users\monic\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
a.status
# Out:
# 400

# %%
data=a.data

# %%
data #String format
# Out:
# b'{"error":{"message":"An access token is required to request this resource.","type":"OAuthException","code":104,"fbtrace_id":"APrPCj_h74Bk0hJs-3qPC94"}}'

# %%
import json
j = json.loads(data) #Json format

# %%
j
# Out:
# {'error': {'message': 'An access token is required to request this resource.',
#   'type': 'OAuthException',
#   'code': 104,
#   'fbtrace_id': 'APrPCj_h74Bk0hJs-3qPC94'}}

# %%
j['error']['code']
# Out:
# 104
